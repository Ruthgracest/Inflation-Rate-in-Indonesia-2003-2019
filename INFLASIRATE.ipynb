# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("/content/drive/My Drive/App/Inflasi - Inflasi (2).csv")

# %% [markdown]
# ##**Data Preparation**##

# %%
df['Month'] = pd.to_datetime(df['Month']).dt.strftime('%b %Y')

# %%
df['Year'] = pd.DatetimeIndex(df['Month']).year

# %%
df['Month']=df.Month.apply(lambda x:x.split(' ')[0])

# %%
import re
df2 = df.drop(np.flatnonzero(df['Inflasi'].str.contains('--', na=False)))
number_re = re.compile(r'\s|<|%|>')
str2float = lambda x: x if np.isreal(x) else number_re.sub('', x, re.U)
df['Inflasi'] = df['Inflasi'].map(str2float).astype(float)

# %%
df.rename(columns={'Inflasi': 'Inflasi (%)'}, inplace=True)

# %% [markdown]
# ##**EDA**##

# %%
df
# Out:
#     Month  Inflasi (%)  Year
# 0     Jun         3.28  2019
# 1     May         3.32  2019
# 2     Apr         2.83  2019
# 3     Mar         2.48  2019
# 4     Feb         2.57  2019
# ..    ...          ...   ...
# 194   Apr         7.62  2003
# 195   Mar         7.17  2003
# 196   Feb         7.60  2003
# 197   Jan         8.68  2003
# 198   Dec         0.00  2002
#
# [199 rows x 3 columns]

# %% [markdown]
# ##**Inflation Rate in Indonesia**

# %% [markdown]
# #2003-2006

# %%
cats = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df['Month'] = pd.Categorical((df['Month']), ordered=True, categories=cats)
plt.figure(figsize=(30,10))
ax=sns.lineplot(data=df[(df.Year.isin([2003,2004,2005,2006]))],x='Month',y='Inflasi (%)', hue='Year').set(title='Nilai Inflasi tahun 2003-2006')

# %% [markdown]
# Tahun **2005** inflasi di Indonesia meningkat drastis menyentuh angka **18%**, hal tersebut terjadi karena saat itu SBY memutuskan memangkas subsidi BBM lewat peningkatan harga BBM  lebih dari dua kali lipat. Angka inflasi di Indonesia berada di antara **14%-19%** hingga **Oktober 2006**. Hal itu dikarenakan hanya minyak internasional sedang meningkat pesat.

# %% [markdown]
# #2007-2010

# %%
cats = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df['Month'] = pd.Categorical((df['Month']), ordered=True, categories=cats)
plt.figure(figsize=(30,10))
ax = sns.lineplot(data=df[(df.Year.isin([2007,2008,2009,2010]))],x='Month',y='Inflasi (%)', hue='Year', palette='viridis').set(title='Nilai Inflasi tahun 2007-2010')

# %% [markdown]
# Tidak banyak terjadi perubahan besar inflasi dari akhir tahun 2006-2007. Namun pada tahun 2008 harga minyak dunia berada dipuncaknya yang menyebabkan harga BBM di Indonesia kembali naik dan besar inflasi Indonesia kembali melonjak ditambah lagi terjadi demonstrasi-demonstrasi di Indonesia saat itu. **Tahun 2009** nilai inflasi di Indonesia sangat turun rata-rata **3%-5%** karena harga BBM juga sudah diturunkan SBY mengingat hal itu merupakan salah satu strategi karena akan maju untuk Pemilu kedua.

# %% [markdown]
# #2011-2014

# %%
cats = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df['Month'] = pd.Categorical((df['Month']), ordered=True, categories=cats)
plt.figure(figsize=(30,10))
ax = sns.lineplot(data=df[(df.Year.isin([2011,2012,2013,2014]))],x='Month',y='Inflasi (%)', hue='Year', palette='viridis').set(title='Nilai Inflasi tahun 2011-2014')

# %% [markdown]
# Harga minyak internasional 2012 melonjak kembali tetapi pemerintah menunda menaikkan harga BBM di tahun 2012. Namun menaikkannya pada **tahun 2013** sehingga menyebabkan inflasi meningkat lagi di angka sekitar **8,5%**. Di **tahun 2014** besar inflasi mulai pulih dan sempat di angka **4,5%** yaitu target dari BI namun **Agustus 2014** terlihat mulai menaik **sampai Desember 2014** karena pemilu dan pelantikan presiden baru dan Jokowi menaikkan kembali harga BBM bersubsidi.

# %% [markdown]
# #2015-2018

# %%
cats = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df['Month'] = pd.Categorical((df['Month']), ordered=True, categories=cats)
plt.figure(figsize=(30,10))
ax=sns.lineplot(data=df[(df.Year.isin([2015,2016,2017,2018]))],x='Month',y='Inflasi (%)', hue='Year', palette='viridis').set(title='Nilai Inflasi tahun 2015-2018')

# %% [markdown]
# Tahun 2015 harga minyak global sudah turun drastis dan angka inflasi di Indonesia mulai terkendali. **Tahun 2016-2018** nilai fluktuasi nilai inflasi di Indonesia tidak terlalu significant rata-rata berada di **3%-5%**. Jika ada kenaikan sedikit terjadi karena penyebab lokal seperti Hari Raya Idul Fitri, Natal, dll.

# %% [markdown]
# #2019

# %%
cats = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
df['Month'] = pd.Categorical((df['Month']), ordered=True, categories=cats)
plt.figure(figsize=(30,10))
ax = sns.lineplot(data=df[(df['Year']==2019)],x='Month',y='Inflasi (%)', hue='Year', palette='viridis').set(title='Nilai Inflasi tahun 2019')

# %% [markdown]
# **Maret 2019** terjadi kenaikan tetapi tidak menyentuh 5% hal tersebut terjadi karena diadakan pemilihan presiden, selain itu sekitar bulan **April-Mei** sempat terjadi demonstrasi.
